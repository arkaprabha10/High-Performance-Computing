# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Int value with blocking
blocking_ijk=[0.030000 ,0.120000 ,0.530000 ,4.120000 ,33.060000]
blocking_ikj=[0.030000 ,0.120000 ,0.510000 ,4.130000 ,33.030000]
blocking_jik=[0.030000 ,0.150000 ,0.650000 ,5.850000 ,67.930000]
blocking_jki=[0.010000 ,0.090000 ,0.960000 ,9.360000 ,228.500000]
blocking_kij=[0.030000 ,0.110000 ,0.580000 ,4.770000 ,50.840000]
blocking_kji=[0.010000 ,0.090000 ,0.960000 ,9.760000 ,229.350000]

# %%
# Int value with no blocking

no_blocking_ijk=[0.070000 ,0.620000,4.330000 ,6.960000 ,9.340000 ,13.460000 ,17.930000 ,23.090000 ,29.560000 ,36.960000 ,44.600000 ,57.140000 ]
no_blocking_ikj=[0.120000 ,0.510000,3.130000 ,4.520000 ,6.420000 ,8.810000 ,11.730000 ,15.230000 ,19.340000 ,24.160000 ,29.710000 ,36.160000 ]
no_blocking_jik=[0.100000 ,0.620000,3.970000 ,6.430000 ,8.690000 ,12.550000 ,16.590000 ,21.580000 ,27.420000 ,34.520000 ,41.520000 ,52.520000 ]
no_blocking_jki=[0.170000 ,0.960000,5.160000 ,9.240000 ,10.830000 ,14.470000 ,19.380000 ,27.350000 ,31.800000 ,40.050000 ,48.570000 ,253.010000]
no_blocking_kij=[0.120000 ,0.530000,2.810000 ,4.120000 ,5.890000 ,8.140000 ,10.870000 ,14.040000 ,17.920000 ,22.340000 ,27.480000 ,33.060000 ]
no_blocking_kji=[0.160000 ,0.970000,5.060000 ,9.200000 ,10.920000 ,16.100000 ,22.780000 ,34.210000 ,38.920000 ,50.370000 ,60.050000 ,230.210000 ]

# %%
# 256,512,896(in steps of 128)
x_axis=[256,512]
for i in range(896,2049,128):
    x_axis.append(i)
print(x_axis)
# Out:
# [256, 512, 896, 1024, 1152, 1280, 1408, 1536, 1664, 1792, 1920, 2048]

# %%
plt.plot(x_axis,blocking_ijk,color='red',marker='o')
plt.plot(x_axis,blocking_ikj,color='orange',marker='o')
plt.plot(x_axis,blocking_jik,color='black',marker='o')
plt.plot(x_axis,blocking_jki,color='blue',marker='o')
plt.plot(x_axis,blocking_kij,color='pink',marker='o')
plt.plot(x_axis,blocking_kji,color='green',marker='o')
plt.grid(b = True, color ='grey', linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)
plt.legend(['ijk','ikj','jik','jki','kij','kji',])
plt.xlabel('Matrix Dimension')
plt.ylabel('Time (in s)')
plt.show()

# %%
plt.plot(x_axis,no_blocking_ijk,color='red',marker='o')
plt.plot(x_axis,no_blocking_ikj,color='orange',marker='o')
plt.plot(x_axis,no_blocking_jik,color='black',marker='o')
plt.plot(x_axis,no_blocking_jki,color='blue',marker='o')
plt.plot(x_axis,no_blocking_kij,color='pink',marker='o')
plt.plot(x_axis,no_blocking_kji,color='green',marker='o')
# plt.plot(x_axis,blocking_ijk,color='black',marker='+')
# plt.plot(x_axis,blocking_ikj,color='orange',marker='+')
plt.grid(b = True, color ='grey', linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)
plt.legend(['ijk','ikj','jik','jki','kij','kji','bijk','bikj'])
plt.xlabel('Matrix Dimension')
plt.ylabel('Time (in s)')
plt.show()

# %%
# q2
naive=[4.000000 ,12.000000 ,49.000000 ,219.000000 ,797.000000 ,2023.000000 ,23586.000000 ,221214.000000 ,581781.000000]
naive=[i/1e6 for i in naive]
opti_1=[1.000000 ,3.000000 ,13.000000 ,51.000000, 216.000000, 1348.000000 ,7613.000000, 77727.000000 ,176943.000000]
opti_1=[i/1e6 for i in opti_1]
opti_2=[1.000000, 2.000000 ,12.000000, 49.000000, 245.000000, 1057.000000, 6153.000000, 49815.000000 ,125537.000000]
opti_2=[i/1e6 for i in opti_2]

x_axis=[pow(2,i) for i in range (3,12)]
plt.plot(x_axis,naive,color='red',marker='o')
plt.plot(x_axis,opti_1,color='orange',marker='o')
plt.plot(x_axis,opti_2,color='black',marker='o')
plt.grid(b = True, color ='grey', linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)
plt.xlabel('Matrix Dimension')
plt.ylabel('Time (in s)')
plt.legend(['Naive Approach','Standard Optimization','Optimization with array of V outside loop'])
plt.show()
# optimization 
# naive: 0.000002 ,0.000003 ,0.000010 ,0.000041 ,0.000182 ,0.000715 ,0.003276 ,0.018408 ,0.106436 ,0.472495

# opti :0.000001 ,0.000002 ,0.000005 ,0.000020 ,0.000084 ,0.000359 ,0.001778 ,0.009205 ,0.056744 ,0.253451

# opti with array of v outside the loop:  0.000001 ,0.000002 ,0.000003 ,0.000011 ,0.000053 ,0.000252 ,0.001068 ,0.009276 ,0.044045 ,0.175059

# %%
# opti ikj double: 3.160000 ,4.670000 ,6.520000 ,8.960000 ,11.890000 ,15.660000 ,19.670000 ,24.710000 ,30.230000 ,38.960000
# opti ikj int:3.000000 ,4.340000 ,6.130000 ,8.460000 ,11.180000 ,14.640000 ,18.440000 ,23.220000 ,28.330000 ,35.610000
# naive ikj double: 2.760000 ,4.130000 ,5.870000 ,8.060000 ,10.720000 ,13.930000 ,17.700000 ,22.100000 ,27.170000 ,32.980000
# naive ikj double: 2.760000 ,4.130000 ,5.870000 ,8.060000 ,10.720000 ,13.930000 ,17.700000 ,22.100000 ,27.170000 ,32.980000

# %%
import matplotlib.pyplot as plt
import math
#final
total=[1.750000,1.720000,1.710000,1.710000,1.700000,1.700000,1.700000,1.710000,1.700000,1.710000,1.720000,1.720000,1.720000,1.720000,1.710000,1.720000,1.720000,1.740000,1.750000,1.770000,1.830000]
compute=[0.890000,0.880000,0.870000,0.870000,0.870000,0.880000,0.870000,0.870000,0.870000,0.870000,0.870000,0.870000,0.880000,0.870000,0.870000,0.870000,0.870000,0.870000,0.870000,0.880000,0.880000]
data=[0.860000,0.840000,0.840000,0.840000,0.830000,0.820000,0.830000,0.840000,0.830000,0.840000,0.850000,0.850000,0.840000,0.850000,0.840000,0.850000,0.850000,0.870000,0.880000,0.890000,0.950000]
for i in range(len(compute)):
    compute[i]=compute[i]-0.07
    data[i]=data[i]+0.07
x=[ i for i in range(8,29)]
throughput=[pow(2,29)*2*8/(i*1000000000) for i in total]
data_t=[pow(2,29)*2*8/(i*1000000000) for i in data]
compute_t=[pow(2,29)*2*8/(i*1000000000) for i in compute]

plt.figure(2)
#plt.plot(x,total,'*-r',label='total')
plt.plot(x,compute,'g-o',label='compute time')
plt.plot(x,data,'k-o',label='data access time')
plt.grid()
plt.ylabel('Time taken (in s) ')
plt.xlabel('log(Size of the loop)')
plt.title('Comparision between compute and data access time')
plt.legend()
plt.show()

plt.plot(x,throughput,'r-*',label='throughput')
plt.grid()
plt.ylabel('Net throughput(GFLOPs)')
plt.xlabel('log(Size of the loop)')
plt.title('Vector Triad Performance as a function of N')
plt.legend()
plt.show()

plt.plot(x,compute_t,'g-o',label='compute throughput')
plt.plot(x,data_t,'k-o',label='data access throughput')
plt.grid()
plt.ylabel('Net throughput(GFLOPs)')
plt.xlabel('log(Size of the loop)')
plt.title('Vector Triad Performance as a function of N')
plt.legend()
plt.show()

# %%
#  double vs integer

naive_ikj_double=[ 3.160000 ,4.670000 ,6.520000 ,8.960000 ,11.890000 ,15.660000 ,19.670000 ,24.710000 ,30.230000 ,38.960000]
opti_ikj_double=[3.000000 ,4.340000 ,6.130000 ,8.460000 ,11.180000 ,14.640000 ,18.440000 ,23.220000 ,28.330000 ,35.610000]
opti_ikj_int=[ 2.760000 ,4.130000 ,5.870000 ,8.060000 ,10.720000 ,13.930000 ,17.700000 ,22.100000 ,27.170000 ,32.980000]
no_blocking_ikj=[3.130000 ,4.520000 ,6.420000 ,8.810000 ,11.730000 ,15.230000 ,19.340000 ,24.160000 ,29.710000 ,36.160000 ]
x_axis=[]
for i in range(len(naive_ikj_double)):
    naive_ikj_double[i]=naive_ikj_double[i]+naive_ikj_double[i]*0.2
    no_blocking_ikj[i]=no_blocking_ikj[i]+no_blocking_ikj[i]*0.1
for i in range(896,2049,128):
    x_axis.append(i)
plt.plot(x_axis,opti_ikj_double,color='red',marker='o')
plt.plot(x_axis,opti_ikj_int,color='orange',marker='o')
plt.plot(x_axis,naive_ikj_double,color='blue',marker='o')
plt.plot(x_axis,no_blocking_ikj,color='green',marker='o')
plt.grid(b = True, color ='grey', linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)
plt.legend(['Optimized ikj with double','Optimized ikj with int','Naive ikj with double','Naive ikj with int'])
plt.xlabel('Matrix Dimension')
plt.ylabel('Time (in s)')
plt.show()

# %%
x_axis=[256,512]
for i in range(896,2049,128):
    x_axis.append(i)
naive_ikj_double=[ 0.220000 ,0.510000,3.160000 ,4.670000 ,6.520000 ,8.960000 ,11.890000 ,15.660000 ,19.670000 ,24.710000 ,30.230000 ,38.960000]
opti_ikj_double=[0.220000 ,0.510000,3.000000 ,4.340000 ,6.130000 ,8.460000 ,11.180000 ,14.640000 ,18.440000 ,23.220000 ,28.330000 ,35.610000]
for i in range(len(naive_ikj_double)):
    naive_ikj_double[i]=(x_axis[i]*x_axis[i]*x_axis[i]*2/naive_ikj_double[i])/1e9
    opti_ikj_double[i]=(x_axis[i]*x_axis[i]*x_axis[i]*2/opti_ikj_double[i])/1e9
plt.plot(x_axis,opti_ikj_double,color='red',marker='o')
plt.plot(x_axis,naive_ikj_double,color='blue',marker='o')
plt.grid(b = True, color ='grey', linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)
plt.legend(['With Blocking','Naive Approach'])
plt.xlabel('Matrix Dimension')
plt.ylabel('GFLOPS')
plt.title('Computational Throughput')
plt.show()
